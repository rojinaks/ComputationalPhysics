# %%
import numpy as np
import matplotlib.pyplot as plt


points = np.random.uniform(low=-1, high=1, size=(2, 100_000))
r_squared = (points**2).sum(axis=0)
plt.hist(np.sqrt(r_squared), density=True, bins=20)

x = np.linspace(0, 2, 400)
plt.plot(x, [dist(x) for x in x])
